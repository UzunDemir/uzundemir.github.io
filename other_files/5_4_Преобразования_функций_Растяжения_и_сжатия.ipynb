# %% [markdown]
# <a href="https://colab.research.google.com/github/UzunDemir/uzundemir.github.io/blob/master/other_files/5_4_%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B9_%D0%A0%D0%B0%D1%81%D1%82%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B8_%D1%81%D0%B6%D0%B0%D1%82%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-5, -4, -3, -2, -1, 1, 2, 3, 4, 5])
    points_Y = np.array([23, 19, 5, 7, 3, 2, 9, 19, 8, 22])
    plt.xlim(-15, 15)
    plt.ylim(-5, 40)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
x = Symbol('x')
f = x**2 / 3
f
# Out:
#  2
# x
# --
# 3

# %%
print_points_ands_function1(f)
# Out:
# MSE = 95.65555555555554

# %%
f_new = 3 * f + 1 
print_points_ands_function1(f_new)
# Out:
# MSE = 23.7

# %%
f_new2 = f_new / 2
print_points_ands_function1(f_new2)
# Out:
# MSE = 55.5
